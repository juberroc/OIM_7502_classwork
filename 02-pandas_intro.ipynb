# %% [markdown]
# # Introduction to pandas
# * The premier data science library
# * The name pandas derives from panel data
# * Has two main objects : DataFrame, Series
# * Is a wrapper around, among other libraries, NumPy and matplotlib
# * Series is a vector of data with an index
# * DataFrame is a collection of Series with a single index (columns are also an index)
# * Was developed by a quant working for a hedge fund, long since semi-retired by the age of about 27

# %%
import matplotlib as plt
import numpy as np
import numpy.random as npr
import pandas as pd
# Out:
# /var/folders/jd/f_y1zkqx7qj3nlzj3h0lgsbc0000gn/T/ipykernel_31037/2767112849.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.0'

# %% [markdown]
# ### 1. make a Series

# %%
norms = pd.Series(npr.standard_normal(10))
norms.values

rands = pd.Series(npr.randn(10))
rands.head(3)
# Out:
# 0    1.546176
# 1   -0.890589
# 2    0.806742
# dtype: float64

# %%
norms.mean()
norms.median()
# Out:
# -0.27302458431355986

# %%
norms.describe()
# Out:
# count    10.000000
# mean     -0.409126
# std       1.171290
# min      -2.480504
# 25%      -1.200450
# 50%      -0.273025
# 75%       0.501292
# max       1.245777
# dtype: float64

# %% [markdown]
# ### 2. make a DataFrame

# %%
df = pd.DataFrame([rands, norms])
df = df.T
df
# Out:
#           0         1
# 0  1.546176 -1.220837
# 1 -0.890589 -0.756780
# 2  0.806742  0.582136
# 3 -1.099231  0.388181
# 4 -0.241404 -2.480504
# 5 -0.691235 -1.139287
# 6  0.343056 -1.459667
# 7  0.626890  0.210731
# 8 -0.623166  1.245777
# 9 -0.134065  0.538996

# %%
data = pd.read_csv('/Users/julioberrocal/Desktop/Classes/Winter 2024/Advanced Programming/OIM7502_SP24/data/GBTC.csv')
data.head()
# Out:
#          Date   Open   High   Low  Close  Adj Close   Volume
# 0  2022-12-15  8.210  8.353  8.14   8.30       8.30  2934400
# 1  2022-12-16  8.055  8.130  7.90   7.93       7.93  3795900
# 2  2022-12-19  7.935  8.400  7.93   8.13       8.13  3558400
# 3  2022-12-20  8.125  8.300  7.84   8.08       8.08  3390300
# 4  2022-12-21  8.000  8.070  7.92   8.05       8.05  2538200

# %%
data['Open']
# Out:
# 0       8.210000
# 1       8.055000
# 2       7.935000
# 3       8.125000
# 4       8.000000
#          ...
# 247    33.520000
# 248    32.939999
# 249    33.470001
# 250    35.209999
# 251    34.349998
# Name: Open, Length: 252, dtype: float64

# %%
data[['Open','Close', 'Volume']]
# Out:
#           Open      Close   Volume
# 0     8.210000   8.300000  2934400
# 1     8.055000   7.930000  3795900
# 2     7.935000   8.130000  3558400
# 3     8.125000   8.080000  3390300
# 4     8.000000   8.050000  2538200
# ..         ...        ...      ...
# 247  33.520000  32.459999  7478900
# 248  32.939999  33.419998  4411500
# 249  33.470001  35.590000  6212200
# 250  35.209999  34.900002  5263500
# 251  34.349998  33.619999  1876793
#
# [252 rows x 3 columns]

# %%
data[['Open', 'Close']].describe()  #for specific columns

data.describe( ) #for all columns
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean    17.851032   18.298841   17.484686   17.896849   17.896849
# std      6.321910    6.430031    6.233768    6.340476    6.340476
# min      7.745000    7.970000    7.730000    7.800000    7.800000
# 25%     13.375000   13.562500   13.030000   13.367500   13.367500
# 50%     17.355001   17.765000   17.035001   17.280000   17.280000
# 75%     19.872501   20.335000   19.600000   19.886250   19.886250
# max     35.430000   36.230000   34.849998   35.590000   35.590000
#
#              Volume
# count  2.520000e+02
# mean   3.354038e+06
# std    2.085299e+06
# min    9.244000e+05
# 25%    2.030250e+06
# 50%    2.735800e+06
# 75%    4.166025e+06
# max    1.955520e+07

# %%
change = data['Close'].pct_change()
change
# Out:
# 0           NaN
# 1     -0.044578
# 2      0.025221
# 3     -0.006150
# 4     -0.003713
#          ...
# 247   -0.085891
# 248    0.029575
# 249    0.064931
# 250   -0.019387
# 251   -0.036676
# Name: Close, Length: 252, dtype: float64

# %%
instant = np.log(data['Close']).diff()
instant
# Out:
# 0           NaN
# 1     -0.045602
# 2      0.024908
# 3     -0.006169
# 4     -0.003720
#          ...
# 247   -0.089806
# 248    0.029146
# 249    0.062910
# 250   -0.019578
# 251   -0.037366
# Name: Close, Length: 252, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       252 non-null    object
#  1   Open       252 non-null    float64
#  2   High       252 non-null    float64
#  3   Low        252 non-null    float64
#  4   Close      252 non-null    float64
#  5   Adj Close  252 non-null    float64
#  6   Volume     252 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB

# %% [markdown]
# ### 3. Dates and Indexes

# %%
data
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2022-12-15   8.210000   8.353000   8.140000   8.300000   8.300000
# 1    2022-12-16   8.055000   8.130000   7.900000   7.930000   7.930000
# 2    2022-12-19   7.935000   8.400000   7.930000   8.130000   8.130000
# 3    2022-12-20   8.125000   8.300000   7.840000   8.080000   8.080000
# 4    2022-12-21   8.000000   8.070000   7.920000   8.050000   8.050000
# ..          ...        ...        ...        ...        ...        ...
# 247  2023-12-11  33.520000  33.750000  31.930000  32.459999  32.459999
# 248  2023-12-12  32.939999  33.590000  32.810001  33.419998  33.419998
# 249  2023-12-13  33.470001  35.619999  33.400002  35.590000  35.590000
# 250  2023-12-14  35.209999  35.330002  34.417999  34.900002  34.900002
# 251  2023-12-15  34.349998  34.400002  33.599998  33.619999  33.619999
#
#       Volume
# 0    2934400
# 1    3795900
# 2    3558400
# 3    3390300
# 4    2538200
# ..       ...
# 247  7478900
# 248  4411500
# 249  6212200
# 250  5263500
# 251  1876793
#
# [252 rows x 7 columns]

# %%
data.index = data.Date
data.drop(columns=['Date']) #only makes a view of the panel

data.drop(columns=['Date'], inplace= True) #inplace = True edits the data frame
data
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2022-12-15   8.210000   8.353000   8.140000   8.300000   8.300000  2934400
# 2022-12-16   8.055000   8.130000   7.900000   7.930000   7.930000  3795900
# 2022-12-19   7.935000   8.400000   7.930000   8.130000   8.130000  3558400
# 2022-12-20   8.125000   8.300000   7.840000   8.080000   8.080000  3390300
# 2022-12-21   8.000000   8.070000   7.920000   8.050000   8.050000  2538200
# ...               ...        ...        ...        ...        ...      ...
# 2023-12-11  33.520000  33.750000  31.930000  32.459999  32.459999  7478900
# 2023-12-12  32.939999  33.590000  32.810001  33.419998  33.419998  4411500
# 2023-12-13  33.470001  35.619999  33.400002  35.590000  35.590000  6212200
# 2023-12-14  35.209999  35.330002  34.417999  34.900002  34.900002  5263500
# 2023-12-15  34.349998  34.400002  33.599998  33.619999  33.619999  1876793
#
# [252 rows x 6 columns]

# %%
# need to give pandas an aggregate function, i.e. mean, std, first, last

data['Close'].mean()
# Out:
# 17.896849115079366

# %% [markdown]
# ### 4. Slicing index loc vs. iloc

# %%
data.iloc[:5] #to slice using integers
# Out:
#              Open   High   Low  Close  Adj Close   Volume
# Date
# 2022-12-15  8.210  8.353  8.14   8.30       8.30  2934400
# 2022-12-16  8.055  8.130  7.90   7.93       7.93  3795900
# 2022-12-19  7.935  8.400  7.93   8.13       8.13  3558400
# 2022-12-20  8.125  8.300  7.84   8.08       8.08  3390300
# 2022-12-21  8.000  8.070  7.92   8.05       8.05  2538200

# %%
data.loc['2022-12-15':'2022-12-21'] #to slice using actual value in data frame (this case is dates)
# Out:
#              Open   High   Low  Close  Adj Close   Volume
# Date
# 2022-12-15  8.210  8.353  8.14   8.30       8.30  2934400
# 2022-12-16  8.055  8.130  7.90   7.93       7.93  3795900
# 2022-12-19  7.935  8.400  7.93   8.13       8.13  3558400
# 2022-12-20  8.125  8.300  7.84   8.08       8.08  3390300
# 2022-12-21  8.000  8.070  7.92   8.05       8.05  2538200

# %% [markdown]
# ### 5. Slicing columns (columns a second index in DataFrames)

# %%
# or data['Close']

# %%
# reorders columns alphabetically

# %% [markdown]
# ### 6. Renaming columns

# %%
# what gives?

# %% [markdown]
# ### 7. Reordering columns

# %% [markdown]
# ### 8. Removing columns or rows

# %%
# set inplace=True to drop the column from original dataset

# %% [markdown]
# ### 9. Sorting

# %%
# sort in descending order - sorts on index

data.sort_index(ascending= False)
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2023-12-15  34.349998  34.400002  33.599998  33.619999  33.619999  1876793
# 2023-12-14  35.209999  35.330002  34.417999  34.900002  34.900002  5263500
# 2023-12-13  33.470001  35.619999  33.400002  35.590000  35.590000  6212200
# 2023-12-12  32.939999  33.590000  32.810001  33.419998  33.419998  4411500
# 2023-12-11  33.520000  33.750000  31.930000  32.459999  32.459999  7478900
# ...               ...        ...        ...        ...        ...      ...
# 2022-12-21   8.000000   8.070000   7.920000   8.050000   8.050000  2538200
# 2022-12-20   8.125000   8.300000   7.840000   8.080000   8.080000  3390300
# 2022-12-19   7.935000   8.400000   7.930000   8.130000   8.130000  3558400
# 2022-12-16   8.055000   8.130000   7.900000   7.930000   7.930000  3795900
# 2022-12-15   8.210000   8.353000   8.140000   8.300000   8.300000  2934400
#
# [252 rows x 6 columns]

# %%
data.sort_values(by='Close', ascending= False)
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2023-12-13  33.470001  35.619999  33.400002  35.590000  35.590000  6212200
# 2023-12-08  34.349998  35.520000  34.299999  35.509998  35.509998  3690700
# 2023-12-05  33.799999  36.080002  33.700001  35.099998  35.099998  8331400
# 2023-12-06  35.430000  36.230000  34.849998  34.919998  34.919998  5929900
# 2023-12-14  35.209999  35.330002  34.417999  34.900002  34.900002  5263500
# ...               ...        ...        ...        ...        ...      ...
# 2022-12-21   8.000000   8.070000   7.920000   8.050000   8.050000  2538200
# 2022-12-29   7.745000   8.040000   7.740000   7.980000   7.980000  4427700
# 2022-12-16   8.055000   8.130000   7.900000   7.930000   7.930000  3795900
# 2022-12-27   8.045000   8.200000   7.850000   7.860000   7.860000  4450000
# 2022-12-28   7.835000   7.970000   7.730000   7.800000   7.800000  3886100
#
# [252 rows x 6 columns]

# %%
# reorders columns alphabetically
data.sort_index(axis=1)
# Out:
#             Adj Close      Close       High        Low       Open   Volume
# Date
# 2022-12-15   8.300000   8.300000   8.353000   8.140000   8.210000  2934400
# 2022-12-16   7.930000   7.930000   8.130000   7.900000   8.055000  3795900
# 2022-12-19   8.130000   8.130000   8.400000   7.930000   7.935000  3558400
# 2022-12-20   8.080000   8.080000   8.300000   7.840000   8.125000  3390300
# 2022-12-21   8.050000   8.050000   8.070000   7.920000   8.000000  2538200
# ...               ...        ...        ...        ...        ...      ...
# 2023-12-11  32.459999  32.459999  33.750000  31.930000  33.520000  7478900
# 2023-12-12  33.419998  33.419998  33.590000  32.810001  32.939999  4411500
# 2023-12-13  35.590000  35.590000  35.619999  33.400002  33.470001  6212200
# 2023-12-14  34.900002  34.900002  35.330002  34.417999  35.209999  5263500
# 2023-12-15  33.619999  33.619999  34.400002  33.599998  34.349998  1876793
#
# [252 rows x 6 columns]

# %%
# value_counts - useful summarization method for aggregating categorical data
data.index.value_counts()
# Out:
# Date
# 2022-12-15    1
# 2023-08-25    1
# 2023-08-08    1
# 2023-08-09    1
# 2023-08-10    1
#              ..
# 2023-04-25    1
# 2023-04-26    1
# 2023-04-27    1
# 2023-04-28    1
# 2023-12-15    1
# Name: count, Length: 252, dtype: int64

# %%
bikes = pd.read_csv('/Users/julioberrocal/Desktop/Classes/Winter 2024/Advanced Programming/OIM7502_SP24/data/Bikeshare.csv')

# %%
bikes
# Out:
#       Unnamed: 0  season mnth  day  hr  holiday  weekday  workingday  \
# 0              1       1  Jan    1   0        0        6           0
# 1              2       1  Jan    1   1        0        6           0
# 2              3       1  Jan    1   2        0        6           0
# 3              4       1  Jan    1   3        0        6           0
# 4              5       1  Jan    1   4        0        6           0
# ...          ...     ...  ...  ...  ..      ...      ...         ...
# 8640        8641       1  Dec  365  19        0        6           0
# 8641        8642       1  Dec  365  20        0        6           0
# 8642        8643       1  Dec  365  21        0        6           0
# 8643        8644       1  Dec  365  22        0        6           0
# 8644        8645       1  Dec  365  23        0        6           0
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered  bikers
# 0         clear  0.24  0.2879  0.81     0.0000       3          13      16
# 1         clear  0.22  0.2727  0.80     0.0000       8          32      40
# 2         clear  0.22  0.2727  0.80     0.0000       5          27      32
# 3         clear  0.24  0.2879  0.75     0.0000       3          10      13
# 4         clear  0.24  0.2879  0.75     0.0000       0           1       1
# ...         ...   ...     ...   ...        ...     ...         ...     ...
# 8640      clear  0.42  0.4242  0.54     0.2239      19          73      92
# 8641      clear  0.42  0.4242  0.54     0.2239       8          63      71
# 8642      clear  0.40  0.4091  0.58     0.1940       2          50      52
# 8643      clear  0.38  0.3939  0.62     0.1343       2          36      38
# 8644      clear  0.36  0.3788  0.66     0.0000       4          27      31
#
# [8645 rows x 16 columns]

# %%
bikes['weathersit'].value_counts()
# Out:
# weathersit
# clear              5645
# cloudy/misty       2218
# light rain/snow     781
# heavy rain/snow       1
# Name: count, dtype: int64

# %%
bikes[bikes['weathersit'] == 'heavy rain/snow']
# Out:
#      Unnamed: 0  season mnth  day  hr  holiday  weekday  workingday  \
# 585         586       1  Jan   26  16        0        3           1
#
#           weathersit  temp  atemp   hum  windspeed  casual  registered  bikers
# 585  heavy rain/snow  0.22  0.197  0.93     0.3284       1          35      36

# %%
bikes['weathersit'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='weathersit'>
